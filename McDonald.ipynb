# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional for pretty plots
# %matplotlib inline
sns.set_style('whitegrid')

# %%
df = pd.read_csv('McDonald.csv')  # Replace with your filename

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
category_counts = df['Category'].value_counts()

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
category_counts = df['Category'].value_counts()
category_counts
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %%
category_counts = df['Category'].value_counts().reset_index()
category_counts.columns = ['Category', 'Count']
category_counts
# Out:
#              Category  Count
# 0        Coffee & Tea     95
# 1           Breakfast     42
# 2  Smoothies & Shakes     28
# 3      Chicken & Fish     27
# 4           Beverages     27
# 5         Beef & Pork     15
# 6      Snacks & Sides     13
# 7            Desserts      7
# 8              Salads      6

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=category_counts, y='Count', x='Category' ) 
plt.title('Number of Food Items per Category', fontsize=14)
plt.xlabel('Number of Items')
plt.ylabel('Food Category')
plt.tight_layout()
plt.show()

# %%
numeric_data = df.select_dtypes(include='number')
numeric_data
# Out:
#      Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0         300                120       13.0                         20
# 1         250                 70        8.0                         12
# 2         370                200       23.0                         35
# 3         450                250       28.0                         43
# 4         400                210       23.0                         35
# ..        ...                ...        ...                        ...
# 255       510                150       17.0                         26
# 256       690                200       23.0                         35
# 257       340                100       11.0                         17
# 258       810                290       32.0                         50
# 259       410                150       16.0                         25
#
#      Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# ...

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=numeric_data, orient='h')
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
def detect_outliers_iqr(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers[[column]]

# %%
detect_outliers_iqr('Calories')
# Out:
#     Calories
# 31      1090
# 32      1150
# 33       990
# 34      1050
# 81       940
# 82      1880

# %%
detect_outliers_iqr('Calories from Fat')
# Out:
#     Calories from Fat
# 31                510
# 32                540
# 81                530
# 82               1060

# %%
detect_outliers_iqr('Total Fat')
# Out:
#     Total Fat
# 31       56.0
# 32       60.0
# 81       59.0
# 82      118.0

# %%
detect_outliers_iqr('Total Fat (% Daily Value)')
# Out:
#     Total Fat (% Daily Value)
# 31                         87
# 32                         93
# 81                         91
# 82                        182

# %%
detect_outliers_iqr('Saturated Fat')
# Out:
# Empty DataFrame
# Columns: [Saturated Fat]
# Index: []

# %%
detect_outliers_iqr('Saturated Fat (% Daily Value)')
# Out:
# Empty DataFrame
# Columns: [Saturated Fat (% Daily Value)]
# Index: []

# %%
detect_outliers_iqr('Trans Fat')
# Out:
#      Trans Fat
# 5          1.0
# 18         1.0
# 24         0.5
# 25         0.5
# 26         1.5
# 42         1.0
# 43         1.5
# 44         1.5
# 45         1.5
# 46         1.5
# 47         2.5
# 49         0.5
# 50         1.0
# 51         1.5
# 52         1.0
# 53         1.0
# 54         1.0
# 55         1.0
# 63         0.5
# 70         0.5
# 72         0.5
# 73         0.5
# 74         0.5
# 82         1.0
# 180        0.5
# 185        0.5
# 186        0.5
# 191        0.5
# 192        0.5
# 213        0.5
# 219        0.5
# 223        1.0
# 224        1.0
# 225        1.0
# 226        1.0
# 227        1.0
# 228        1.5
# 229        1.0
# 230        1.0
# 231        1.5
# 241        1.0
# 242        1.0
# 243        1.0
# 244        1.0
# 245        1.0
# 246        1.0
# 247        1.0
# 248        1.0
# 249        1.0
# 250        1.0
# 251        1.0
# 252        0.5
# 253        1.0
# 255        0.5
# 256        1.0
# 258        1.0

# %%
detect_outliers_iqr('Cholesterol')
# Out:
#     Cholesterol
# 0           260
# 3           285
# 5           300
# 6           250
# 7           250
# 12          250
# 13          250
# 18          280
# 19          250
# 22          265
# 24          275
# 26          295
# 27          555
# 28          555
# 31          575
# 32          575
# 47          160
# 82          265

# %%
detect_outliers_iqr('Cholesterol (% Daily Value)')
# Out:
#     Cholesterol (% Daily Value)
# 0                            87
# 3                            95
# 5                           100
# 6                            83
# 7                            83
# 12                           83
# 13                           83
# 18                           93
# 19                           84
# 22                           89
# 24                           92
# 26                           99
# 27                          185
# 28                          185
# 31                          192
# 32                          192
# 47                           53
# 82                           89

# %%
detect_outliers_iqr('Sodium')
# Out:
#     Sodium
# 31    2150
# 32    2260
# 33    2170
# 34    2290
# 82    3600

# %%
detect_outliers_iqr('Sodium (% Daily Value)')
# Out:
#     Sodium (% Daily Value)
# 31                      90
# 32                      94
# 33                      91
# 34                      95
# 82                     150

# %%
detect_outliers_iqr('Carbohydrates')
# Out:
#      Carbohydrates
# 31             111
# 32             116
# 33             110
# 34             115
# 82             118
# 231            111
# 242            109
# 243            135
# 245            114
# 246            140
# 248            114
# 249            141
# 250            109
# 251            135
# 253            139
# 256            106
# 258            114

# %%
 detect_outliers_iqr('Carbohydrates (% Daily Value)')
# Out:
#      Carbohydrates (% Daily Value)
# 31                              37
# 32                              39
# 33                              37
# 34                              38
# 82                              39
# 231                             37
# 242                             36
# 243                             45
# 245                             38
# 246                             47
# 248                             38
# 249                             47
# 250                             36
# 251                             45
# 253                             46
# 258                             38

# %%
  detect_outliers_iqr('Dietary Fiber')
# Out:
# Empty DataFrame
# Columns: [Dietary Fiber]
# Index: []

# %%
  detect_outliers_iqr('Dietary Fiber (% Daily Value)')
# Out:
#     Dietary Fiber (% Daily Value)
# 32                             28
# 34                             28
# 88                             28
# 89                             28

# %%
  detect_outliers_iqr('Sugars')
# Out:
#      Sugars
# 246     123
# 249     120
# 251     115
# 253     128

# %%
  detect_outliers_iqr('Protein')
# Out:
#     Protein
# 47       48
# 81       44
# 82       87

# %%
  detect_outliers_iqr('Vitamin A (% Daily Value)')
# Out:
#      Vitamin A (% Daily Value)
# 70                          60
# 71                          60
# 72                          60
# 73                          60
# 74                          60
# 75                          70
# 76                          60
# 77                          60
# 84                         170
# 85                         100
# 86                         110
# 87                         160
# 88                         170
# 89                         170
# 100                         45
# 239                         40
# 240                         50

# %%
  detect_outliers_iqr('Vitamin C (% Daily Value)')
# Out:
#      Vitamin C (% Daily Value)
# 24                          15
# 25                          15
# 40                         130
# 41                         130
# 44                          15
# 45                          20
# 51                          25
# 59                          20
# 60                          20
# 61                          20
# 62                          20
# 63                          25
# 64                          30
# 70                          20
# 71                          25
# 72                          15
# 73                          15
# 74                          15
# 75                          15
# 76                          15
# 77                          15
# 82                          15
# 84                          30
# 85                          25
# 86                          30
# 87                          25
# 88                          30
# 89                          30
# 96                          30
# ...

# %%
detect_outliers_iqr('Calcium (% Daily Value)')
# Out:
#      Calcium (% Daily Value)
# 246                       70
# 253                       70

# %%
detect_outliers_iqr('Iron (% Daily Value)')
# Out:
#     Iron (% Daily Value)
# 31                    40
# 32                    40

# %% [markdown]
# **dietry fibre, saturated fat and daturated fay (% daily value ) have no outlier else all of them have outlier**

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
correlation_matrix = df.corr(numeric_only=True)
print(correlation_matrix)
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
corr_pairs = correlation_matrix.unstack()
corr_pairs = corr_pairs[corr_pairs != 1]
highest_corr = corr_pairs.sort_values(ascending=False).drop_duplicates()
print(highest_corr.head(1))
# Out:
# Sodium (% Daily Value)  Sodium    0.999929
# dtype: float64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **Highest correlation of variable is Sodium (% Daily Value)  Sodium    0.999929**

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
a = 'Cholesterol (% Daily Value)'

# %%
category_cholesterol = df.groupby('Category')[a].mean()

# %%
category_cholesterol_sorted = category_cholesterol.sort_values(ascending=False)
print(category_cholesterol_sorted)
# Out:
# Category
# Breakfast             50.952381
# Beef & Pork           28.933333
# Chicken & Fish        25.222222
# Salads                17.333333
# Smoothies & Shakes    14.714286
# Coffee & Tea           9.378947
# Snacks & Sides         6.230769
# Desserts               4.857143
# Beverages              0.185185
# Name: Cholesterol (% Daily Value), dtype: float64

# %%
max_category = category_cholesterol_sorted.idxmax()
max_value = category_cholesterol_sorted.max()

print(f"Category contributing most to Cholesterol (% DV): {max_category} ({max_value}%)")
# Out:
# Category contributing most to Cholesterol (% DV): Breakfast (50.95238095238095%)

# %% [markdown]
# **Category contributing most to Cholesterol (% DV): Breakfast (50.95238095238095%)**

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
b= 'sodium'

# %%
max_sodium_row = df.loc[df['Sodium'].idxmax()]
print(max_sodium_row[['Item', 'Sodium']])
# Out:
# Item      Chicken McNuggets (40 piece)
# Sodium                            3600
# Name: 82, dtype: object

# %%
print(max_sodium_row[['Category', 'Item', 'Sodium']])
# Out:
# Category                  Chicken & Fish
# Item        Chicken McNuggets (40 piece)
# Sodium                              3600
# Name: 82, dtype: object

# %% [markdown]
# **chicken and fish is max contain sodium**

# %%
top_4_saturated_fat = df.sort_values(by='Saturated Fat', ascending=False).head(4)

top_4_saturated_fat[['Category', 'Item', 'Saturated Fat']]
# Out:
#                Category                                         Item  \
# 231        Coffee & Tea                Frappé Chocolate Chip (Large)
# 82       Chicken & Fish                 Chicken McNuggets (40 piece)
# 32            Breakfast  Big Breakfast with Hotcakes (Large Biscuit)
# 253  Smoothies & Shakes         McFlurry with M&M’s Candies (Medium)
#
#      Saturated Fat
# 231           20.0
# 82            20.0
# 32            20.0
# 253           20.0
